# %%
name = "Dhruva"
age = 21

print("Name:", name)
print("Age:", age)
# Out:
# Name: Dhruva
# Age: 21

# %%
a = 10
b = 20

print("Sum =", a + b)
print("Product =", a * b)
# Out:
# Sum = 30
# Product = 200

# %%
n = int(input("Enter a number : "))
if n >2 :
    print("Greater than 2")
else:
    print("Less than or equal to 2")
# Out:
# Greater than 2

# %%
n1 = int(input("Enter first number : "))
n2 = int(input("Enter second number : "))
ch = input("Enter operation (+, -, *, /) : ")
if ch == '+':
    print("Sum =", n1 + n2)
elif ch == '-':
    print("Difference =", n1 - n2)
elif ch == '*':
    print("Product =", n1 * n2)
elif ch == '/':
    print("Quotient =", n1 / n2)
# Out:
# Product = 1035

# %%
n = input("Do you want to celsius or farenheit (c/f): ")
if n == "f":
    f = float(input("Enter temperature in Farenheit : "))
    c = (f - 32) * 5/9
    print("Temperature in Celsius :", c)
elif n == "c":
    c = float(input("Enter temperature in Celsius : "))
    f = (c * 9/5) + 32
    print("Temperature in Farenheit :", f)
# Out:
# Temperature in Farenheit : 132.8

# %%
name  = input("Enter your name :")
print("Welcome to evoketechnologies ", name)
# Out:
# Welcome to evoketechnologies  vasu
