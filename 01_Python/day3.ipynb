# %%
import student_utels
while True:
    try:
        print("Student Records")
        choice = int(input("Enter your choice (1-4): "))
        if choice == 1:
            print(student_utels.add())
        elif choice == 2:
            student_utels.view()
        elif choice == 3:
            print(student_utels.delete())
        elif choice == 4:
            print("Exiting...")
            break
        else:
            print("Invalid choice. Please enter a number between 1 and 4.")
    except ValueError:
        print("Invalid input. Please enter a number.")
# Out:
# Student Records
# Invalid choice. Please enter a number between 1 and 4.
# Student Records
# Invalid choice. Please enter a number between 1 and 4.
# Student Records
# Exiting...
